# %% [markdown]
# # Título del notebook

# %% [markdown]
# ## Introducción
#
# - Objetivo del Notebook

# %% [markdown]
# ## Librerías

# %% [markdown]
# ## Funciones Aux.

# %% [markdown]
# ## Carga de datos

# %% [markdown]
# ## Secciones

# %% [markdown]
# ## Conclusiones
